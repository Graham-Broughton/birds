# %%
import cv2
import audioread
import logging
import os
import sys

sys.path.append('../pytorch-image-models-master')
import random
import time
import warnings
import glob

import librosa
import numpy as np
import pandas as pd
import soundfile as sf
import timm
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as torchdata

from contextlib import contextmanager
from pathlib import Path
from typing import List
from typing import Optional
from sklearn import metrics

from tqdm import tqdm

import albumentations as A
import albumentations.pytorch.transforms as T

import concurrent.futures

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def init_layer(layer):
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, "bias"):
        if layer.bias is not None:
            layer.bias.data.fill_(0.0)


def init_bn(bn):
    bn.bias.data.fill_(0.0)
    bn.weight.data.fill_(1.0)


def init_weights(model):
    classname = model.__class__.__name__
    if classname.find("Conv2d") != -1:
        nn.init.xavier_uniform_(model.weight, gain=np.sqrt(2))
        model.bias.data.fill_(0)
    elif classname.find("BatchNorm") != -1:
        model.weight.data.normal_(1.0, 0.02)
        model.bias.data.fill_(0)
    elif classname.find("GRU") != -1:
        for weight in model.parameters():
            if len(weight.size()) > 1:
                nn.init.orghogonal_(weight.data)
    elif classname.find("Linear") != -1:
        model.weight.data.normal_(0, 0.01)
        model.bias.data.zero_()


def interpolate(x: torch.Tensor, ratio: int):
    """Interpolate data in time domain. This is used to compensate the
    resolution reduction in downsampling of a CNN.
    Args:
      x: (batch_size, time_steps, classes_num)
      ratio: int, ratio to interpolate
    Returns:
      upsampled: (batch_size, time_steps * ratio, classes_num)
    """
    (batch_size, time_steps, classes_num) = x.shape
    upsampled = x[:, :, None, :].repeat(1, 1, ratio, 1)
    upsampled = upsampled.reshape(batch_size, time_steps * ratio, classes_num)
    return upsampled


def pad_framewise_output(framewise_output: torch.Tensor, frames_num: int):
    """Pad framewise_output to the same length as input frames. The pad value
    is the same as the value of the last frame.
    Args:
      framewise_output: (batch_size, frames_num, classes_num)
      frames_num: int, number of frames to pad
    Outputs:
      output: (batch_size, frames_num, classes_num)
    """
    output = F.interpolate(
        framewise_output.unsqueeze(1), size=(frames_num, framewise_output.size(2)), align_corners=True, mode="bilinear"
    ).squeeze(1)

    return output


class AttBlockV2(nn.Module):
    def __init__(self, in_features: int, out_features: int, activation="linear"):
        super().__init__()

        self.activation = activation
        self.att = nn.Conv1d(in_channels=in_features, out_channels=out_features, kernel_size=1, stride=1, padding=0, bias=True)
        self.cla = nn.Conv1d(in_channels=in_features, out_channels=out_features, kernel_size=1, stride=1, padding=0, bias=True)

        self.init_weights()

    def init_weights(self):
        init_layer(self.att)
        init_layer(self.cla)

    def forward(self, x):
        # x: (n_samples, n_in, n_time)
        norm_att = torch.softmax(torch.tanh(self.att(x)), dim=-1)
        cla = self.nonlinear_transform(self.cla(x))
        x = torch.sum(norm_att * cla, dim=2)
        return x, norm_att, cla

    def nonlinear_transform(self, x):
        if self.activation == 'linear':
            return x
        elif self.activation == 'sigmoid':
            return torch.sigmoid(x)


class TimmSED(nn.Module):
    def __init__(self, base_model_name: str, config=None, pretrained=False, num_classes=24, in_channels=1):
        super().__init__()

        self.config = config

        self.bn0 = nn.BatchNorm2d(self.config.n_mels)

        base_model = timm.create_model(
            base_model_name,
            pretrained=pretrained,
            num_classes=0,
            global_pool="",
            in_chans=in_channels,
        )

        layers = list(base_model.children())[:-2]
        self.encoder = nn.Sequential(*layers)

        in_features = base_model.num_features

        self.fc1 = nn.Linear(in_features, in_features, bias=True)
        self.att_block = AttBlockV2(in_features, num_classes, activation="sigmoid")

        self.init_weight()

    def init_weight(self):
        init_bn(self.bn0)
        init_layer(self.fc1)

    def forward(self, input_data):
        if self.config.in_channels == 3:
            x = input_data
        else:
            x = input_data[:, [0], :, :]  # (batch_size, 1, time_steps, mel_bins)

        frames_num = x.shape[2]

        x = x.transpose(1, 3)
        x = self.bn0(x)
        x = x.transpose(1, 3)

        x = x.transpose(2, 3)

        x = self.encoder(x)

        # Aggregate in frequency axis
        x = torch.mean(x, dim=2)

        x1 = F.max_pool1d(x, kernel_size=3, stride=1, padding=1)
        x2 = F.avg_pool1d(x, kernel_size=3, stride=1, padding=1)
        x = x1 + x2

        x = x.transpose(1, 2)
        x = F.relu_(self.fc1(x))
        x = x.transpose(1, 2)

        (clipwise_output, norm_att, segmentwise_output) = self.att_block(x)

        output_dict = {
            "clipwise_output": clipwise_output,
        }

        return output_dict

# %%
mean = 0.485  # R only for RGB
std = 0.229  # R only for RGB

albu_transforms = {
    'train': A.Compose(
        [
            A.Normalize(mean, std),
        ]
    ),
    'valid': A.Compose(
        [
            A.Normalize(mean, std),
        ]
    ),
}


mean2 = (0.485, 0.456, 0.406)  # RGB
std2 = (0.229, 0.224, 0.225)  # RGB

albu_transforms2 = {
    'train': A.Compose(
        [
            A.Normalize(mean2, std2),
        ]
    ),
    'valid': A.Compose(
        [
            A.Normalize(mean2, std2),
        ]
    ),
}

# %%
class CFG_tf_efficientnet_b0:
    batch_size = 4
    num_workers = 4

    n_mels = 256
    fmin = 16
    fmax = 16386
    n_fft = 2048
    hop_length = 512
    sr = 32000

    target_columns = "abethr1 abhori1 abythr1 afbfly1 afdfly1 afecuc1 affeag1 afgfly1 afghor1 afmdov1 afpfly1 afpkin1 afpwag1 afrgos1 afrgrp1 afrjac1 afrthr1 amesun2 augbuz1 bagwea1 barswa bawhor2 bawman1 bcbeat1 beasun2 bkctch1 bkfruw1 blacra1 blacuc1 blakit1 blaplo1 blbpuf2 blcapa2 blfbus1 blhgon1 blhher1 blksaw1 blnmou1 blnwea1 bltapa1 bltbar1 bltori1 blwlap1 brcale1 brcsta1 brctch1 brcwea1 brican1 brobab1 broman1 brosun1 brrwhe3 brtcha1 brubru1 brwwar1 bswdov1 btweye2 bubwar2 butapa1 cabgre1 carcha1 carwoo1 categr ccbeat1 chespa1 chewea1 chibat1 chtapa3 chucis1 cibwar1 cohmar1 colsun2 combul2 combuz1 comsan crefra2 crheag1 crohor1 darbar1 darter3 didcuc1 dotbar1 dutdov1 easmog1 eaywag1 edcsun3 egygoo equaka1 eswdov1 eubeat1 fatrav1 fatwid1 fislov1 fotdro5 gabgos2 gargan gbesta1 gnbcam2 gnhsun1 gobbun1 gobsta5 gobwea1 golher1 grbcam1 grccra1 grecor greegr grewoo2 grwpyt1 gryapa1 grywrw1 gybfis1 gycwar3 gyhbus1 gyhkin1 gyhneg1 gyhspa1 gytbar1 hadibi1 hamerk1 hartur1 helgui hipbab1 hoopoe huncis1 hunsun2 joygre1 kerspa2 klacuc1 kvbsun1 laudov1 lawgol lesmaw1 lessts1 libeat1 litegr litswi1 litwea1 loceag1 lotcor1 lotlap1 luebus1 mabeat1 macshr1 malkin1 marsto1 marsun2 mcptit1 meypar1 moccha1 mouwag1 ndcsun2 nobfly1 norbro1 norcro1 norfis1 norpuf1 nubwoo1 pabspa1 palfly2 palpri1 piecro1 piekin1 pitwhy purgre2 pygbat1 quailf1 ratcis1 raybar1 rbsrob1 rebfir2 rebhor1 reboxp1 reccor reccuc1 reedov1 refbar2 refcro1 reftin1 refwar2 rehblu1 rehwea1 reisee2 rerswa1 rewsta1 rindov rocmar2 rostur1 ruegls1 rufcha2 sacibi2 sccsun2 scrcha1 scthon1 shesta1 sichor1 sincis1 slbgre1 slcbou1 sltnig1 sobfly1 somgre1 somtit4 soucit1 soufis1 spemou2 spepig1 spewea1 spfbar1 spfwea1 spmthr1 spwlap1 squher1 strher strsee1 stusta1 subbus1 supsta1 tacsun1 tafpri1 tamdov1 thrnig1 trobou1 varsun2 vibsta2 vilwea1 vimwea1 walsta1 wbgbir1 wbrcha2 wbswea1 wfbeat1 whbcan1 whbcou1 whbcro2 whbtit5 whbwea1 whbwhe3 whcpri2 whctur2 wheslf1 whhsaw1 whihel1 whrshr1 witswa1 wlwwar wookin1 woosan wtbeat1 yebapa1 yebbar1 yebduc1 yebere1 yebgre1 yebsto1 yeccan1 yefcan yelbis1 yenspu1 yertin1 yesbar1 yespet1 yetgre1 yewgre1".split()

    base_model_name = "tf_efficientnet_b0_ns"
    pretrained = False
    num_classes = 264
    in_channels = 1

    ckpt_path = Path.mkdir(Path.cwd().parent / 'models', exist_ok=True)

# %%
config_tf_efficientnet_b0 = CFG_tf_efficientnet_b0()

# config_enesemble = [
#     config_tf_efficientnet_b0,
# ]

# %%
def compute_melspec(y, params):
    """
    Computes a mel-spectrogram and puts it at decibel scale
    Arguments:
        y {np array} -- signal
        params {AudioParams} -- Parameters to use for the spectrogram. Expected to have the attributes sr, n_mels, f_min, f_max
    Returns:
        np array -- Mel-spectrogram
    """
    melspec = librosa.feature.melspectrogram(
        y=y,
        sr=params.sr,
        n_mels=params.n_mels,
        n_fft=params.n_fft,
        hop_length=params.hop_length,
        fmin=params.fmin,
        fmax=params.fmax,
    )

    return melspec


def mono_to_color(X, eps=1e-6, mean=None, std=None):
    """
    Converts a one channel array in [0, 255]
    Arguments:
        X {numpy array [H x W]} -- 2D array to convert
    Keyword Arguments:
        eps {float} -- To avoid dividing by 0 (default: {1e-6})
        mean {None or np array} -- Mean for normalization (default: {None})
        std {None or np array} -- Std for normalization (default: {None})
    Returns:
        numpy array [1 x H x W] -- RGB numpy array
    """
    # X = np.stack([X, X, X], axis=-1)
    X = np.expand_dims(X, axis=-1)

    # Standardize
    mean = mean or X.mean()
    std = std or X.std()
    X = (X - mean) / (std + eps)

    # Normalize to [0, 255]
    _min, _max = X.min(), X.max()

    if (_max - _min) > eps:
        V = np.clip(X, _min, _max)
        V = 255 * (V - _min) / (_max - _min)
        V = V.astype(np.uint8)
    else:
        V = np.zeros_like(X, dtype=np.uint8)

    return V


def mono_to_color3(X, eps=1e-6, mean=None, std=None):
    """
    Converts a one channel array to a 3 channel one in [0, 255]
    Arguments:
        X {numpy array [H x W]} -- 2D array to convert
    Keyword Arguments:
        eps {float} -- To avoid dividing by 0 (default: {1e-6})
        mean {None or np array} -- Mean for normalization (default: {None})
        std {None or np array} -- Std for normalization (default: {None})
    Returns:
        numpy array [3 x H x W] -- RGB numpy array
    """
    X = np.stack([X, X, X], axis=-1)

    # Standardize
    mean = mean or X.mean()
    std = std or X.std()
    X = (X - mean) / (std + eps)

    # Normalize to [0, 255]
    _min, _max = X.min(), X.max()

    if (_max - _min) > eps:
        V = np.clip(X, _min, _max)
        V = 255 * (V - _min) / (_max - _min)
        V = V.astype(np.uint8)
    else:
        V = np.zeros_like(X, dtype=np.uint8)

    return V

# %%
class TestDataset(torchdata.Dataset):
    def __init__(
        self,
        df: pd.DataFrame,
        clip: np.ndarray,
        config=None,
    ):
        self.df = df
        self.clip = clip
        self.config = config

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx: int):
        sample = self.df.loc[idx, :]
        row_id = sample.row_id

        end_seconds = int(sample.seconds)
        start_seconds = int(end_seconds - 5)

        y = self.clip[self.config.sr * start_seconds : self.config.sr * end_seconds].astype(np.float32)

        image = compute_melspec(y, self.config)
        image = librosa.power_to_db(image.astype(np.float32), ref=np.max)

        if self.config.in_channels == 3:
            image = mono_to_color3(image)
            image = image.astype(np.uint8)
            image = albu_transforms2['valid'](image=image)['image'].T
        else:
            image = mono_to_color(image)
            image = image.astype(np.uint8)
            image = albu_transforms['valid'](image=image)['image'].T

        return {
            "image": image,
            "row_id": row_id,
        }

# %%
class TrainDataset(torchdata.Dataset):
    def __init__(
        self,
        df: pd.DataFrame,
        clip: np.ndarray,
        config=None,
    ):
        self.df = df
        self.clip = clip
        self.config = config

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx: int):
        sample = self.df.loc[idx, :]
        row_id = sample.row_id

        end_seconds = int(sample.seconds)
        start_seconds = int(end_seconds - 5)

        y = self.clip[self.config.sr * start_seconds : self.config.sr * end_seconds].astype(np.float32)

        image = compute_melspec(y, self.config)
        image = librosa.power_to_db(image.astype(np.float32), ref=np.max)

        if self.config.in_channels == 3:
            image = mono_to_color3(image)
            image = image.astype(np.uint8)
            image = albu_transforms2['valid'](image=image)['image'].T
        else:
            image = mono_to_color(image)
            image = image.astype(np.uint8)
            image = albu_transforms['valid'](image=image)['image'].T

        return {
            "image": image,
            "row_id": row_id,
        }

# %%
# models_ensemble = []

# for config in config_enesemble:

#     config_models = []

#     for ckpt_path in config.ckpt_path:

#         model = TimmSED(
#             base_model_name=config.base_model_name,
#             config=config,
#             pretrained=config.pretrained,
#             num_classes=config.num_classes,
#             in_channels=config.in_channels
#         )

#         model.load_state_dict(torch.load(ckpt_path, map_location=device))
#         model.eval()

#         config_models.append(model)

#     models_ensemble.append((config, config_models))

# all_audios = list(Path("../input/birdclef-2023/test_soundscapes/").glob("*.ogg"))*15

# %%
models_ensemble = []

config = config_tf_efficientnet_b0

model = TimmSED(
    base_model_name=config.base_model_name,
    config=config,
    pretrained=config.pretrained,
    num_classes=config.num_classes,
    in_channels=config.in_channels
)

all_audios = list((Path.cwd().parent / 'data' / "train_audio").glob("**/*.ogg"))*15
# Out:
# /home/broug/mambaforge/envs/kaggle/lib/python3.11/site-packages/timm/models/_factory.py:114: UserWarning: Mapping deprecated model name tf_efficientnet_b0_ns to current tf_efficientnet_b0.ns_jft_in1k.
#   model = create_fn(

# %%
all_audios
# Out:
# [PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC354694.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC687329.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC293554.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC447027.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC746540.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC445355.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC687331.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC293487.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC322388.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC371225.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC512852.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC687332.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC746121.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC509609.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC371194.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC748247.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC529126.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC474458.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC746120.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC348306.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC746541.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC267912.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC267910.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC529125.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/fatrav1/XC267911.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC374070.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC418248.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC326157.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC368137.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC530152.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC254851.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC195149.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC491811.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC146329.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC752949.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC396206.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC374068.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC533788.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC497605.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC332371.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC374071.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC137090.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC361400.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC448867.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC609488.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC612384.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC687589.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC496369.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC304508.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC366578.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC282039.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC713507.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC233058.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC433861.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC746032.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC679612.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC426280.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC667405.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC153534.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC634833.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC302347.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC131309.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC530153.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC499226.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC547982.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spemou2/XC472378.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC366686.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC601810.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC444920.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC755404.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC594009.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC217014.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC567812.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC581947.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC251867.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC537114.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC728975.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC593164.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/spfbar1/XC607574.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC415368.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC690354.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC600810.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC267513.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC288797.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC402683.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC601095.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC297597.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC267977.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC481723.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC332250.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC440536.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC476163.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC288749.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC267512.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC397515.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC347695.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/vimwea1/XC660999.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC210337.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC237765.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC410588.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC285544.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC537113.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC210336.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC138679.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC701859.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC701339.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC247898.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC237763.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC293978.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC294696.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC616594.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC444351.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC444915.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC281992.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC701668.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC748259.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC237761.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC616589.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC398382.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC131311.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC608033.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC131661.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC117140.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC252342.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC138678.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC282020.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC364252.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC396427.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC748260.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/ruegls1/XC117142.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/pabspa1/XC398387.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/pabspa1/XC398465.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/pabspa1/XC752935.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/pabspa1/XC234411.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/pabspa1/XC394648.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/pabspa1/XC398472.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/pabspa1/XC750199.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/bawman1/XC294912.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/bawman1/XC413941.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/bawman1/XC206436.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/bawman1/XC237894.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/bawman1/XC115075.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/bawman1/XC320114.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/bawman1/XC614627.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC418815.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC290026.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC216298.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC470858.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC401890.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC233900.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC400004.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC113258.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC282030.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC294717.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC285554.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC601535.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC373666.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC189465.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC244441.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC396429.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC527256.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC195764.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC421001.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC426138.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC524189.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC195150.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC610255.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC378463.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC431722.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC465953.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC470575.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC530129.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC611575.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC441679.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC269872.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC128201.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC486930.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC420114.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC316684.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC142129.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC317118.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC45691.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC366273.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC166369.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC317504.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC364274.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC283886.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC697060.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC153908.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC527253.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC267981.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC202626.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC522785.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC521445.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC476293.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC269378.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC348899.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC402305.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC440836.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC660980.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC315441.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC227268.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC402051.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC345109.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC394085.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC235192.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC240628.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC419282.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC609490.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC608130.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC120617.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC530128.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC697055.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC611573.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC136670.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC524433.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC293969.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC254842.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC289265.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC446295.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC136671.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC608029.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC419291.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC750197.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC455343.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC581112.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC412604.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC530132.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC292857.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC527270.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC213631.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC431770.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC692104.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC722033.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC366275.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC201218.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC265022.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC611574.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC295703.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC235194.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC423346.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC697676.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC299343.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC129091.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC316065.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC57022.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC410446.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC711306.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC470857.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC203210.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC697096.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC629233.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC293968.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC537105.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC294386.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC239621.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC205678.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC338394.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC527895.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC301604.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC547977.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC214532.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC664421.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC478384.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC294993.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC722836.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC166370.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC127483.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC366274.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC598058.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC692103.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC333235.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC236844.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC506089.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC550065.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC750196.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC516105.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC247285.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC600779.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC470595.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC265023.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC247370.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC605215.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC177991.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC281996.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC375395.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC307169.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC195528.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC268626.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC309429.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC254841.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC233902.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC267104.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC348897.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC498558.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC366267.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC694797.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC439780.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC424325.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC394699.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC239622.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC158074.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC207988.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC420487.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC459508.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC297598.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC486011.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC118212.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC395641.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC366271.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC263028.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC348903.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC174855.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC603149.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC703359.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC136668.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC233901.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC395639.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC522784.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC530150.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC205679.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC715790.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC619369.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC603151.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC748252.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC659842.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC400465.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC697062.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC267720.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC213630.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC605216.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC756783.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC440204.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC603150.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC293907.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC650541.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC398893.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC660998.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC402104.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC269908.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC366270.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC610568.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC393725.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC339465.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC610069.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC527933.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC45693.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC607218.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC136669.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC253356.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC444577.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC138402.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC597063.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC611410.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC610567.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC305643.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC366268.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC610861.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC527894.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC524187.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC530151.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC130952.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC173241.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC530127.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC530130.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC440168.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC450237.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC366269.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC447250.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC548658.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC400464.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC598342.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC370292.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC614373.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC34014.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC724066.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC200957.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC697677.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC615090.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC17975.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC521443.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC377490.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/gnbcam2/XC521444.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC412152.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633770.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC467138.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC516636.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633686.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC424180.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC342113.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633945.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC467139.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC326213.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC680731.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633662.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC462100.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC350707.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC455392.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633749.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC237781.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633930.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC623489.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC424824.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC460491.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC368148.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC608520.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC189760.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633751.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC584051.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC634126.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC620816.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC382900.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC588711.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC289335.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC395697.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633901.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633900.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC247926.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC664381.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC512776.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC634160.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC605958.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633899.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC243509.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC701564.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC368152.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC704922.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC353955.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC291506.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC634180.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC608049.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC195851.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC397703.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633887.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633666.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC650865.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC240661.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633668.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC623488.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC28648.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC633897.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC247642.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC459543.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC453678.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC247925.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC442059.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC459554.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC195853.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC392017.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC459544.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC634055.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC512294.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC721281.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC341996.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC445669.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC620820.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC315026.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC672145.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC326214.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC467140.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC316925.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC703819.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC467141.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC412168.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC195852.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC391988.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC453055.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC703846.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC429222.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC323362.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC190645.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC247923.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC322541.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC645946.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC634175.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC392056.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/grbcam1/XC634108.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC433872.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC747721.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC374141.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC294219.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC240828.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC337024.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC472392.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC374140.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC753435.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC294741.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC530752.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC747720.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC397673.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC424435.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC234941.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC56502.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC555510.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC472393.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC531563.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC234942.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC472391.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC253492.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC509305.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC293971.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC509304.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC196083.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/wbgbir1/XC587610.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/afpkin1/XC704863.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC144235.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC625433.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC596284.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC644448.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC151184.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC237256.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC142380.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC641996.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC120169.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC704818.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC687906.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC582341.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC624903.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC594510.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC532306.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC666954.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC446908.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC301894.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC193216.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC513468.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC308383.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC627718.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC672493.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC502262.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC626650.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC554260.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC405094.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC377836.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC665246.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC718226.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC193612.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC601827.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC670701.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC564929.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC326677.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC739003.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC659695.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC382539.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC563178.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC709594.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC170643.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC494347.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC211900.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC660121.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC424543.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC606998.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC579720.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC621631.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC511685.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC298583.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC415177.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC263048.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC521622.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC303047.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC112692.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC627267.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC292432.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC216974.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC294352.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC189732.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC639017.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC581967.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC580586.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC426204.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC533692.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC542010.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC441885.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC712672.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC670343.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC628957.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC199771.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC584693.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC623152.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC669953.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC382082.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC665227.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC613336.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC625438.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC486941.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC622410.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC279728.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC430273.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC526851.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC453947.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC638218.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC745792.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC661610.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC156307.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC189735.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC549048.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC638316.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC140833.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC538678.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC125314.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC667098.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC754794.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC335909.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC626969.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC686301.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC193849.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC612706.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC741216.ogg'),
# ...
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC344206.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC717603.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC292984.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC612697.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC628264.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC155409.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC289866.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC419544.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC694886.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC144284.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC620287.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC641158.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC195421.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC533173.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC128575.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC490034.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC728944.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC403178.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC725284.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC658351.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC566788.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC630123.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC177142.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC595832.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC207934.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC612901.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC341721.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC326512.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC486944.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC486942.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC605687.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC594370.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC614108.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC114415.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC638629.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC533897.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC539055.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC337218.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC583670.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC738389.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC488714.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC552836.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC576520.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC189738.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC616645.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC672494.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC447825.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC612695.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC153194.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC742518.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC569424.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC143391.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC323547.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC583531.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC655983.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC363901.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC144257.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC626528.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC511684.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC193852.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC458051.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC452830.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC489181.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC651914.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC512890.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC193357.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC485344.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC185035.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC125105.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC638485.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC625439.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC333375.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC538532.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC669937.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC612696.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC533691.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC337811.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC433308.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC494276.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC581056.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC569996.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC179299.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC637884.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC388032.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC662573.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC527745.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC463273.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC623202.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC411022.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC690064.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC377837.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC659491.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC624904.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC292433.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC138324.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC448430.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC337672.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC693023.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC578537.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC742540.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC641994.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC240250.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC621446.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC618683.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC310842.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC711870.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC569998.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC418097.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC638047.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC189245.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC357802.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC608698.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC463639.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC698338.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC583384.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC399801.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC189733.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC692059.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC660623.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC618756.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC627885.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC638807.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC522317.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC256900.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC678169.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC480593.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC568238.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC384120.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC619514.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC326517.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC151185.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC500730.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC637599.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC624253.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC485623.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC756803.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC627882.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC408351.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC402976.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC711814.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC298732.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC688154.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC381577.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC617082.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC538277.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC189785.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC638480.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC139550.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC522513.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC377233.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC499654.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC601994.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC199225.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC606997.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC343993.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC649218.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC528622.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC535823.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC446909.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC685378.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC624906.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC647788.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC627883.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC638482.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC570742.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC533690.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC669936.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC431422.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC641626.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC504189.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC631740.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC298844.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC42427.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC576544.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC486943.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC579930.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC628927.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC621679.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC282376.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC545293.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC555949.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC419543.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC380756.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/combuz1/XC568243.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC459325.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC305002.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC604512.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC313872.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC227563.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC240617.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC307296.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC509640.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC610995.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC270167.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC442841.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC313874.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC664563.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC530163.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC164106.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC413958.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC227618.ogg'),
#  PosixPath('/home/broug/Desktop/birds/data/train_audio/lessts1/XC286501.ogg'),
#  ...]

# %%
seconds = [i for i in range(5, 605, 5)]


def prediction_for_clip(audio_path):
    device = torch.device("cpu")

    # inference
    prediction_dict = {}

    global models_ensemble

    clip, _ = librosa.load(audio_path, sr=32000)
    name_ = "_".join(audio_path.name.split(".")[:-1])
    row_ids = [name_ + f"_{second}" for second in seconds]

    test_df = pd.DataFrame({"row_id": row_ids, "seconds": seconds})

    for config_models in models_ensemble:
        config, models = config_models[0], config_models[1]

        dataset = TestDataset(
            df=test_df,
            clip=clip,
            config=config,
        )

        loader = torchdata.DataLoader(
            dataset, batch_size=config.batch_size, num_workers=config.num_workers, drop_last=False, shuffle=False, pin_memory=True
        )

        for data in loader:
            row_ids = data['row_id']

            for row_id in row_ids:
                if row_id not in prediction_dict:
                    prediction_dict[str(row_id)] = []

            image = data['image']  # .to(device)

            probas = []

            for model in models:
                with torch.no_grad():
                    output = model(image)
                #
                for row_id_idx, row_id in enumerate(row_ids):
                    prediction_dict[str(row_id)].append(output['clipwise_output'][[row_id_idx]].numpy().reshape(-1))

    for row_id in list(prediction_dict.keys()):
        logits = np.array(prediction_dict[row_id]).mean(0)
        prediction_dict[row_id] = {}
        for label in range(len(config.target_columns)):
            prediction_dict[row_id][config.target_columns[label]] = logits[label]

    return prediction_dict

# %%
seconds = [i for i in range(5, 605, 5)]


def prediction_for_clip2(audio_path):
    device = torch.device("cpu")

    # inference
    prediction_dict = {}

    global models_ensemble

    clip, _ = librosa.load(audio_path, sr=32000)
    name_ = "_".join(audio_path.name.split(".")[:-1])
    row_ids = [name_ + f"_{second}" for second in seconds]

    train_df = pd.DataFrame({"row_id": row_ids, "seconds": seconds})

    for config_models in models_ensemble:
        config, models = config_models[0], config_models[1]

        dataset = TrainDataset(
            df=train_df,
            clip=clip,
            config=config,
        )

        loader = torchdata.DataLoader(
            dataset, batch_size=config.batch_size, num_workers=config.num_workers, drop_last=False, shuffle=False, pin_memory=True
        )

        for data in loader:
            row_ids = data['row_id']

            for row_id in row_ids:
                if row_id not in prediction_dict:
                    prediction_dict[str(row_id)] = []

            image = data['image']  # .to(device)

            probas = []

            with model.train():
                output = model(image)

            #
            for row_id_idx, row_id in enumerate(row_ids):
                prediction_dict[str(row_id)].append(output['clipwise_output'][[row_id_idx]].numpy().reshape(-1))

        with torch.no_grad():
            output = model(image)

    for row_id in list(prediction_dict.keys()):
        logits = np.array(prediction_dict[row_id]).mean(0)
        prediction_dict[row_id] = {}
        for label in range(len(config.target_columns)):
            prediction_dict[row_id][config.target_columns[label]] = logits[label]

    return prediction_dict

# %%
def crop_or_pad(y, length, sr, train=True, probs=None):
    """
    Crops an array to a chosen length
    Arguments:
        y {1D np array} -- Array to crop
        length {int} -- Length of the crop
        sr {int} -- Sampling rate
    Keyword Arguments:
        train {bool} -- Whether we are at train time. If so, crop randomly, else return the beginning of y (default: {True})
        probs {None or numpy array} -- Probabilities to use to chose where to crop (default: {None})
    Returns:
        1D np array -- Cropped array
    """
    if len(y) <= length:
        y = np.concatenate([y, np.zeros(length - len(y))])
    else:
        if not train:
            start = 0
        elif probs is None:
            start = np.random.randint(len(y) - length)
        else:
            start = np.random.choice(np.arange(len(probs)), p=probs) + np.random.random()
            start = int(sr * (start))

        y = y[start : start + length]

    return y.astype(np.float32)

# %%
# %%time
start = time.time()
dicts = []
for audio_path in all_audios:
    dicts.append(prediction_for_clip2(audio_path))
print(f"Regular for loop costs {time.time()-start} for processing 15 audios")
# Out:
# Regular for loop costs 5.4836273193359375e-05 for processing 15 audios
# CPU times: user 207 µs, sys: 50 µs, total: 257 µs
# Wall time: 269 µs

# %%
start = time.time()
with concurrent.futures.ThreadPoolExecutor(max_workers=4) as executor:
    dicts = list(executor.map(prediction_for_clip2, all_audios))
print(f"With concurrent ThreadPoolExecutor, time cost reduced to {time.time()-start} for processing 15 audios")
# Out:
# With concurrent ThreadPoolExecutor, time cost reduced to 0.0005519390106201172 for processing 15 audios

# %%
prediction_dicts = {}
for d in dicts:
    prediction_dicts.update(d)

# %%
submission = pd.DataFrame.from_dict(prediction_dicts, "index").rename_axis("row_id").reset_index()
submission.to_csv("submission.csv", index=False)
submission.head()
